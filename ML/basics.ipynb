# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Salary_Data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.title('Experience vs Salary')
plt.xlabel('Years of Experience')       
plt.ylabel('Salary')
plt.scatter(df['YearsExperience'], df['Salary'], color='red')
plt.grid()

# %%
#seperating input and output columns
#input -> 2d, output -> 1d
x = df[['YearsExperience']].values
y = df['Salary'].values

# %%
x.ndim
# Out:
# 2

# %%
y.ndim
# Out:
# 1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((24, 1), (6, 1), (24,), (6,))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([9312.57512673])

# %%
lr.intercept_
# Out:
# np.float64(26780.09915062818)

# %%
y_pred = lr.predict(x_test)

# %%
df1=pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1
# Out:
#      Actual      Predicted
# 0   37731.0   40748.961841
# 1  122391.0  122699.622956
# 2   57081.0   64961.657170
# 3   63218.0   63099.142145
# 4  116969.0  115249.562855
# 5  109431.0  107799.502753

# %%
 plt.scatter(x_test, y_test, color='red')

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
# Out:
# 2446.1723690465055

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.988169515729126

# %%
# Plot scatter with fitted regression line
import numpy as np
x_line = np.linspace(df['YearsExperience'].min(), df['YearsExperience'].max(), 100).reshape(-1, 1)
plt.figure(figsize=(6, 4))
plt.scatter(df['YearsExperience'], df['Salary'], color='red', label='Actual')
plt.plot(x_line, lr.predict(x_line), label='Best fit line')
plt.title('Experience vs Salary (Regression Fit)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid()

# %%
#polynomial features 
from sklearn.preprocessing import PolynomialFeatures  
poly = PolynomialFeatures(degree=2)

# %%
x_poly = poly.fit_transform(x)
x_poly
# Out:
# array([[  1.  ,   1.1 ,   1.21],
#        [  1.  ,   1.3 ,   1.69],
#        [  1.  ,   1.5 ,   2.25],
#        [  1.  ,   2.  ,   4.  ],
#        [  1.  ,   2.2 ,   4.84],
#        [  1.  ,   2.9 ,   8.41],
#        [  1.  ,   3.  ,   9.  ],
#        [  1.  ,   3.2 ,  10.24],
#        [  1.  ,   3.2 ,  10.24],
#        [  1.  ,   3.7 ,  13.69],
#        [  1.  ,   3.9 ,  15.21],
#        [  1.  ,   4.  ,  16.  ],
#        [  1.  ,   4.  ,  16.  ],
#        [  1.  ,   4.1 ,  16.81],
#        [  1.  ,   4.5 ,  20.25],
#        [  1.  ,   4.9 ,  24.01],
#        [  1.  ,   5.1 ,  26.01],
#        [  1.  ,   5.3 ,  28.09],
#        [  1.  ,   5.9 ,  34.81],
#        [  1.  ,   6.  ,  36.  ],
#        [  1.  ,   6.8 ,  46.24],
#        [  1.  ,   7.1 ,  50.41],
#        [  1.  ,   7.9 ,  62.41],
#        [  1.  ,   8.2 ,  67.24],
#        [  1.  ,   8.7 ,  75.69],
#        [  1.  ,   9.  ,  81.  ],
#        [  1.  ,   9.5 ,  90.25],
#        [  1.  ,   9.6 ,  92.16],
# ...

# %%
poly_reg = LinearRegression()

# %%
poly_reg.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
poly_reg.score(x_poly, y)
# Out:
# 0.956975168321065
